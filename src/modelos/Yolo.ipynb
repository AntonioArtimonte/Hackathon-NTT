# %%
# !pip install roboflow
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 2.3 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...

# %%
from roboflow import Roboflow
from ultralytics import YOLO

# %%
rf = Roboflow(api_key="QzZVXyUevQT1Rdr73NJE")
project = rf.workspace("treinamento-yolo-msuok").project("pessoas-em-desastre")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.82, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to Pessoas-em-desastre-2 in yolov8:: 100%|██████████| 19230/19230 [00:01<00:00, 19142.30it/s]

# %%
# model = YOLO("yolov8n.yaml")
# results = model.train(data="/home/rodrigo/Repos/Hackathon-NTT/src/dados_desastre_1-1/data.yaml", epochs=150)

# %% [markdown]
# # Teste para usar o pczao ao maximo

# %%
import torch
from ultralytics import YOLO

# # Verificar o número de GPUs disponíveis
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# gpu_count = torch.cuda.device_count()

# # Configuração para uso de múltiplas GPUs
# model = YOLO("yolov8n.yaml").to('cuda')
model = YOLO("yolov8n.yaml")
# if gpu_count > 1:
#     model = torch.nn.DataParallel(model)

# results = model.train(data="/home/linguica/rodrigo/Hackathon-NTT/src/modelos/Pessoas-em-desastre-2/data.yaml", epochs=300, workers=8, amp=True, batch=32)

# results = model.train(
#     data="/home/linguica/rodrigo/Hackathon-NTT/src/modelos/Pessoas-em-desastre-2/data.yaml", 
#     epochs=125, 
#     workers=8, 
#     amp=True, 
#     batch=32, 
#     weight_decay=0.0005, 
#     patience=5, 
# )

results = model.train(
    data="/home/linguica/rodrigo/Hackathon-NTT/src/modelos/Pessoas-em-desastre-2/data.yaml", 
    epochs=125, 
)
# Out:
# Ultralytics YOLOv8.2.82 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (NVIDIA RTX A4000, 16109MiB)
# ...

# %%
model.export(format="onnx")
# Out:
# Ultralytics YOLOv8.2.82 🚀 Python-3.10.12 torch-2.4.0+cu121 CPU (13th Gen Intel Core(TM) i7-13700K)
# YOLOv8n summary (fused): 168 layers, 3,007,013 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/home/linguica/rodrigo/Hackathon-NTT/runs/detect/train2/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 11, 8400) (6.0 MB)
# requirements: Ultralytics requirement ['onnx>=1.12.0'] not found, attempting AutoUpdate...
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 93.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.3/309.3 KB 112.7 MB/s eta 0:00:00
# ...
#
# requirements: AutoUpdate success ✅ 1.9s, installed 1 package: ['onnx>=1.12.0']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
#
# ONNX: starting export with onnx 1.16.2 opset 19...
# ONNX: export success ✅ 2.1s, saved as '/home/linguica/rodrigo/Hackathon-NTT/runs/detect/train2/weights/best.onnx' (11.7 MB)
#
# Export complete (3.3s)
# ...
